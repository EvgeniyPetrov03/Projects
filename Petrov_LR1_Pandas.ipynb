# %%
import pandas as pd
my_series = pd.Series([5,6,7,8,9,10])
my_series
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
my_series.values
# Out:
# array([ 5,  6,  7,  8,  9, 10])

# %%
my_series[4]
# Out:
# 9

# %%
my_series2 = pd.Series([5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd', 'e', 'f'])
my_series2['f']
# Out:
# 10

# %%
my_series2[['a', 'b', 'f']]
# Out:
# a     5
# b     6
# f    10
# dtype: int64

# %%
my_series2[['a', 'b', 'f']] = 0
my_series2
# Out:
# a    0
# b    0
# c    7
# d    8
# e    9
# f    0
# dtype: int64

# %%
my_series2[my_series2 > 0]
# Out:
# c    7
# d    8
# e    9
# dtype: int64

# %%
my_series2[my_series2 > 0] * 2
# Out:
# c    14
# d    16
# e    18
# dtype: int64

# %%
my_series3 = pd.Series({'a': 5, 'b': 6, 'c': 7, 'd': 8})
my_series3
# Out:
# a    5
# b    6
# c    7
# d    8
# dtype: int64

# %%
'd' in my_series3
# Out:
# True

# %%
my_series3.name = 'numbers'
my_series3.index.name = 'letters'
my_series3
# Out:
# letters
# a    5
# b    6
# c    7
# d    8
# Name: numbers, dtype: int64

# %%
my_series3.index = ['A', 'B', 'C', 'D']
my_series3
# Out:
# A    5
# B    6
# C    7
# D    8
# Name: numbers, dtype: int64

# %%
df = pd.DataFrame({'country': ['Belgium', 'France', 'Belarus', 'Ukraine'],'population': [17.04, 143.5, 9.5, 45.5],'square': [2724902, 17125191, 207600, 603628]})
df
# Out:
#    country  population    square
# 0  Belgium       17.04   2724902
# 1   France      143.50  17125191
# 2  Belarus        9.50    207600
# 3  Ukraine       45.50    603628

# %%
df['country']
# Out:
# 0    Belgium
# 1     France
# 2    Belarus
# 3    Ukraine
# Name: country, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['country', 'population', 'square'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.DataFrame({'country': ['Belgium', 'France', 'Belarus', 'Ukraine'],'population': [17.04, 143.5, 9.5, 45.5],'square': [2724902, 17125191, 207600, 603628]}, index=['BE', 'FR', 'BY', 'UA'])
df
# Out:
#     country  population    square
# BE  Belgium       17.04   2724902
# FR   France      143.50  17125191
# BY  Belarus        9.50    207600
# UA  Ukraine       45.50    603628

# %%
df.index = ['BE', 'FR', 'BY', 'UA']
df.index.name = 'Country Code'
df
# Out:
#               country  population    square
# Country Code
# BE            Belgium       17.04   2724902
# FR             France      143.50  17125191
# BY            Belarus        9.50    207600
# UA            Ukraine       45.50    603628

# %%
df['country']
# Out:
# Country Code
# BE    Belgium
# FR     France
# BY    Belarus
# UA    Ukraine
# Name: country, dtype: object

# %%
df.loc['BE']
# Out:
# country       Belgium
# population      17.04
# square        2724902
# Name: BE, dtype: object

# %%
df.iloc[0]
# Out:
# country       Belgium
# population      17.04
# square        2724902
# Name: BE, dtype: object

# %%
df.loc[['BE', 'FR'], 'population']
# Out:
# Country Code
# BE     17.04
# FR    143.50
# Name: population, dtype: float64

# %%
df.loc['BE':'BY', :]
# Out:
#               country  population    square
# Country Code
# BE            Belgium       17.04   2724902
# FR             France      143.50  17125191
# BY            Belarus        9.50    207600

# %%
df[df.population > 10][['country', 'square']]
# Out:
#               country    square
# Country Code
# BE            Belgium   2724902
# FR             France  17125191
# UA            Ukraine    603628

# %%
df.reset_index()
# Out:
#   Country Code  country  population    square
# 0           BE  Belgium       17.04   2724902
# 1           FR   France      143.50  17125191
# 2           BY  Belarus        9.50    207600
# 3           UA  Ukraine       45.50    603628

# %%
df['density'] = df['population'] / df['square'] * 1000000
df
# Out:
#               country  population    square    density
# Country Code
# BE            Belgium       17.04   2724902   6.253436
# FR             France      143.50  17125191   8.379469
# BY            Belarus        9.50    207600  45.761079
# UA            Ukraine       45.50    603628  75.377550

# %%
df.drop(['density'], axis='columns')
# Out:
#               country  population    square
# Country Code
# BE            Belgium       17.04   2724902
# FR             France      143.50  17125191
# BY            Belarus        9.50    207600
# UA            Ukraine       45.50    603628

# %%
df = df.rename(columns={'Country Code': 'country_code'})
df
# Out:
#               country  population    square    density
# Country Code
# BE            Belgium       17.04   2724902   6.253436
# FR             France      143.50  17125191   8.379469
# BY            Belarus        9.50    207600  45.761079
# UA            Ukraine       45.50    603628  75.377550

# %%
titanic_df = pd.read_csv('train.csv')
print(titanic_df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(titanic_df.groupby(['Sex', 'Survived'])['PassengerId'].count())
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
print(titanic_df.groupby(['Pclass', 'Survived'])['PassengerId'].count())
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
pvt = titanic_df.pivot_table(index=['Sex'], columns=['Pclass'], values='Name', aggfunc='count')
pvt
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
from pandas import read_csv, DataFrame, Series
data = read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.pivot_table('PassengerId', 'Pclass', 'Survived', 'count').plot(kind='bar',
stacked=True)

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(ncols=2)
data.pivot_table('PassengerId', ['SibSp'], 'Survived', 'count').plot(ax=axes[0],
title='SibSp')
data.pivot_table('PassengerId', ['Parch'], 'Survived', 'count').plot(ax=axes[1],
title='Parch')

# %%
data.PassengerId[data.Cabin.notnull()].count()
# Out:
# 204

# %%
data.PassengerId[data.Age.notnull()].count()
# Out:
# 714

# %%
data.Age = data.Age.median()

# %%
data.PassengerId[data.Ticket.notnull()].count()
# Out:
# 891

# %%
data.PassengerId[data.Embarked.notnull()].count()
# Out:
# 889

# %%
data.PassengerId[data.Fare.notnull()].count()
# Out:
# 891

# %%
data.PassengerId[data.Name.notnull()].count()
# Out:
# 891

# %%
data[data.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
MaxPassEmbarked = data.groupby('Embarked').count()['PassengerId'] 
data.Embarked[data.Embarked.isnull()] = MaxPassEmbarked[MaxPassEmbarked == MaxPassEmbarked.max()].index[0]
# Out:
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.PassengerId[data.Fare.isnull()]
# Out:
# Series([], Name: PassengerId, dtype: int64)

# %%
data = data.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  28.0      1      0    7.2500        S
# 1           1       1  female  28.0      1      0   71.2833        C
# 2           1       3  female  28.0      0      0    7.9250        S
# 3           1       1  female  28.0      1      0   53.1000        S
# 4           0       3    male  28.0      0      0    8.0500        S
# 5           0       3    male  28.0      0      0    8.4583        Q
# 6           0       1    male  28.0      0      0   51.8625        S
# 7           0       3    male  28.0      3      1   21.0750        S
# 8           1       3  female  28.0      0      2   11.1333        S
# 9           1       2  female  28.0      1      0   30.0708        C
# 10          1       3  female  28.0      1      1   16.7000        S
# 11          1       1  female  28.0      0      0   26.5500        S
# 12          0       3    male  28.0      0      0    8.0500        S
# ...

# %%
import pandas as pd
from pandas import read_csv, DataFrame, Series
data = read_csv('train.csv')

# %%
data.PassengerId[data.Sex =='male'][data.Pclass == 1].count()
# Out:
# 122

# %%
data.PassengerId[data.Age < 14 ][data.Pclass == 2].count()
# Out:
# 18

# %%
data.PassengerId[data.SibSp == 0].count()
# Out:
# 608

# %%
data.PassengerId[data.Embarked =='Q'][data.Fare > data.Fare.median()].count()
# Out:
# 20

# %%
data.Age[data.Sex =='female'].median()
# Out:
# 24.0

# %%
data.PassengerId[data.SibSp == 0][data.Age > 65 ].count()
# Out:
# 7

# %%
children = data
MedianAge = children.groupby('Age').count()['PassengerId']
children.Age[children.Age.isnull()] = MedianAge[MedianAge == MedianAge.median()].index[0]
children[children.Age < 14 ]
# Out:
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 119          120         0       3
# 125          126         1       3
# 147          148         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# ...

# %%
data.groupby('Embarked')['Fare'].median()
# Out:
# Embarked
# C    29.70
# Q     7.75
# S    13.00
# Name: Fare, dtype: float64

# %%
data.groupby('Pclass')['Fare'].median()
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64
